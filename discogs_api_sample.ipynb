# %%
import json
import requests as rs
import requests_cache 

requests_cache.install_cache(cache_name='discogs_cache', backend='sqlite', expire_after=86400)

# Input variables
label_id = "1265272"
min_average = 4.7

# %%
url = "https://api.discogs.com/labels/{}/releases?page=1&per_page=25".format(label_id)
response = rs.get(url)
response_dict = json.loads(response.text)
print(json.dumps(response_dict, indent=4))
# Out:
# {
#     "pagination": {
#         "page": 1,
#         "pages": 2,
#         "per_page": 25,
#         "items": 37,
#         "urls": {
#             "last": "https://api.discogs.com/labels/1265272/releases?page=2&per_page=25",
#             "next": "https://api.discogs.com/labels/1265272/releases?page=2&per_page=25"
#         }
#     },
#     "releases": [
#         {
#             "status": "Accepted",
#             "format": "5xFile, FLAC, EP",
#             "catno": "ARTSCORE 016",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/24998860",
#             "title": "The Dark Welcome",
#             "id": 24998860,
#             "year": 2022,
#             "artist": "Tensal"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, MP3, EP, 320",
#             "catno": "ARTSCORE 016",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26600165",
#             "title": "The Dark Welcome",
#             "id": 26600165,
#             "year": 2022,
#             "artist": "Tensal"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE001",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10446578",
#             "title": "Diamonds & Ashes",
#             "id": 10446578,
#             "year": 2017,
#             "artist": "Emmanuel (8)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE002",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10530622",
#             "title": "Totsuka No Tsurugi",
#             "id": 10530622,
#             "year": 2017,
#             "artist": "I Hate Models"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE003",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11058723",
#             "title": "Sawmill",
#             "id": 11058723,
#             "year": 2017,
#             "artist": "Keith Carnal"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", RP",
#             "catno": "ARTSCORE003",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26606444",
#             "title": "Sawmill",
#             "id": 26606444,
#             "year": 2023,
#             "artist": "Keith Carnal"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE004",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11184384",
#             "title": "Anathema",
#             "id": 11184384,
#             "year": 2017,
#             "artist": "Judas (11)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE005",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13217748",
#             "title": "ARTSCORE005",
#             "id": 13217748,
#             "year": 2019,
#             "artist": "Keith Carnal"
#         },
#         {
#             "status": "Accepted",
#             "format": "4xFile, MP3, 320",
#             "catno": "ARTSCORE005",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15163690",
#             "title": "ARTSCORE005",
#             "id": 15163690,
#             "year": 2019,
#             "artist": "Keith Carnal"
#         },
#         {
#             "status": "Accepted",
#             "format": "4xFile, WAV",
#             "catno": "ARTSCORE006",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14630885",
#             "title": "Hammerhead",
#             "id": 14630885,
#             "year": 2019,
#             "artist": "Yan Cook"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "ARTSCORE006",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13862589",
#             "title": "Hammerhead",
#             "id": 13862589,
#             "year": 2019,
#             "artist": "Yan Cook"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE007",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14048028",
#             "title": "Onryo",
#             "id": 14048028,
#             "year": 2019,
#             "artist": "Introversion (3)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE008",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14298828",
#             "title": "Die Illusion",
#             "id": 14298828,
#             "year": 2019,
#             "artist": "Obscure Shape & SHDW*"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, WAV",
#             "catno": "ARTSCORE008",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15019933",
#             "title": "Die Illusion",
#             "id": 15019933,
#             "year": 2019,
#             "artist": "Obscure Shape & SHDW*"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE009",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14651640",
#             "title": "Time Is Relative",
#             "id": 14651640,
#             "year": 2020,
#             "artist": "Emmanuel (8)"
#         },
#         {
#             "status": "Accepted",
#             "format": "4xFile, FLAC",
#             "catno": "ARTSCORE009",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14822158",
#             "title": " Time Is Relative",
#             "id": 14822158,
#             "year": 2020,
#             "artist": "Emmanuel (8)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE010",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14764037",
#             "title": "Body Brain ",
#             "id": 14764037,
#             "year": 2020,
#             "artist": "Keith Carnal"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "ARTSCORE011",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15231419",
#             "title": "Wave Of Nostalgia EP ",
#             "id": 15231419,
#             "year": 2020,
#             "artist": "Tim Tama"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE012",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15949109",
#             "title": "Superwoman 2\u200b.\u200b0",
#             "id": 15949109,
#             "year": 2020,
#             "artist": "MRD"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE013",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/16270494",
#             "title": "REM",
#             "id": 16270494,
#             "year": 2020,
#             "artist": "Introversion (3)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "ARTSCORE014",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/17372029",
#             "title": "Cold Spots",
#             "id": 17372029,
#             "year": 2021,
#             "artist": "Yan Cook"
#         },
#         {
#             "status": "Accepted",
#             "format": "4xFile, MP3, EP, 320",
#             "catno": "ARTSCORE014",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/17860888",
#             "title": "Cold Spots",
#             "id": 17860888,
#             "year": 2021,
#             "artist": "Yan Cook"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE015",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/24520745",
#             "title": "H O \u03a3 T I L E ",
#             "id": 24520745,
#             "year": 2022,
#             "artist": "Judas (11)"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, FLAC",
#             "catno": "ARTSCORE015",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/24700613",
#             "title": "H O \u03a3 T I L E ",
#             "id": 24700613,
#             "year": 2022,
#             "artist": "Judas (11)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "ARTSCORE016",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/24801965",
#             "title": "The Dark Welcome",
#             "id": 24801965,
#             "year": 2022,
#             "artist": "Tensal"
#         }
#     ]
# }

# %%
# Get community release rating
response_rating_list = []
for release in response_dict["releases"]:
    resource_url = release["resource_url"]
    rating_url = resource_url + "/rating"
    response_rating = rs.get(rating_url)
    response_rating_dict = json.loads(response_rating.text)
    response_rating_list.append(response_rating_dict) 

for item in response_rating_list:
   print(item)
# Out:
# {'release_id': 24998860, 'rating': {'count': 2, 'average': 4.5}}
# {'release_id': 26600165, 'rating': {'count': 2, 'average': 5.0}}
# {'release_id': 10446578, 'rating': {'count': 41, 'average': 4.49}}
# {'release_id': 10530622, 'rating': {'count': 193, 'average': 4.58}}
# {'release_id': 11058723, 'rating': {'count': 57, 'average': 4.56}}
# {'release_id': 26606444, 'rating': {'count': 3, 'average': 4.33}}
# {'release_id': 11184384, 'rating': {'count': 33, 'average': 4.45}}
# {'release_id': 13217748, 'rating': {'count': 26, 'average': 4.27}}
# {'release_id': 15163690, 'rating': {'count': 4, 'average': 4.5}}
# {'release_id': 14630885, 'rating': {'count': 1, 'average': 3.0}}
# {'release_id': 13862589, 'rating': {'count': 21, 'average': 4.38}}
# {'release_id': 14048028, 'rating': {'count': 60, 'average': 4.43}}
# {'release_id': 14298828, 'rating': {'count': 49, 'average': 4.63}}
# {'release_id': 15019933, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 14651640, 'rating': {'count': 20, 'average': 4.5}}
# {'release_id': 14822158, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 14764037, 'rating': {'count': 24, 'average': 4.42}}
# {'release_id': 15231419, 'rating': {'count': 38, 'average': 4.47}}
# {'release_id': 15949109, 'rating': {'count': 57, 'average': 4.58}}
# {'release_id': 16270494, 'rating': {'count': 34, 'average': 4.79}}
# {'release_id': 17372029, 'rating': {'count': 53, 'average': 4.74}}
# {'release_id': 17860888, 'rating': {'count': 2, 'average': 4.5}}
# {'release_id': 24520745, 'rating': {'count': 7, 'average': 5.0}}
# {'message': 'You are making requests too quickly.'}
# {'message': 'You are making requests too quickly.'}

# %%
# Remove duplicates based on the "release_id" key
unique_rating_list = []
seen_ids = set()

for item in response_rating_list:
    item_id = item["release_id"]
    if item_id not in seen_ids:
        seen_ids.add(item_id)
        unique_rating_list.append(item)

for item in unique_rating_list:
   print(item)
# Out:
# {'release_id': 26146235, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 14704507, 'rating': {'count': 14, 'average': 4.79}}
# {'release_id': 10502778, 'rating': {'count': 13, 'average': 4.15}}
# {'release_id': 12402975, 'rating': {'count': 10, 'average': 4.3}}
# {'release_id': 17282449, 'rating': {'count': 20, 'average': 4.75}}
# {'release_id': 23819831, 'rating': {'count': 17, 'average': 4.88}}
# {'release_id': 23824595, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 24753029, 'rating': {'count': 13, 'average': 4.77}}
# {'release_id': 26041843, 'rating': {'count': 16, 'average': 4.69}}
# {'release_id': 28720261, 'rating': {'count': 8, 'average': 4.63}}
# {'release_id': 29138122, 'rating': {'count': 5, 'average': 4.6}}
# {'release_id': 29313661, 'rating': {'count': 0, 'average': 0.0}}

# %%
# Filter releases with average >= min_average
filtered_rating_list = [item for item in unique_rating_list if item["rating"]["average"] >= min_average]

for item in filtered_rating_list:
    print(item)
# Out:
# {'release_id': 14704507, 'rating': {'count': 14, 'average': 4.79}}
# {'release_id': 17282449, 'rating': {'count': 20, 'average': 4.75}}
# {'release_id': 23819831, 'rating': {'count': 17, 'average': 4.88}}
# {'release_id': 23824595, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 24753029, 'rating': {'count': 13, 'average': 4.77}}

# %%
# Create a dictionary mapping release_id to rating_info
rating_info_dict = {item["release_id"]: item["rating"] for item in filtered_rating_list}

# Extract information from response_dict only for matching release_ids
matching_releases = [
    {
        "release_info": release_info,
        "rating_info": rating_info_dict.get(release_info["id"])
    }
    for release_info in response_dict["releases"] if release_info["id"] in rating_info_dict
]

# %%
# Remove duplicates based on the "id" key
unique_matching_list = []
seen_ids = set()

for item in matching_releases:
    item_id = item["release_info"]["id"]
    if item_id not in seen_ids:
        seen_ids.add(item_id)
        unique_matching_list.append(item)

for release in unique_matching_list:
    print("Release Info:")
    print(json.dumps(release["release_info"], indent=4))
    print("Rating Info:")
    print(json.dumps(release["rating_info"], indent=4))
    print()
# Out:
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\", EP",
#     "catno": "LIP003",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/14704507",
#     "title": "Euphoria",
#     "id": 14704507,
#     "year": 2020,
#     "artist": "Ferdinger"
# }
# Rating Info:
# {
#     "count": 14,
#     "average": 4.79
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\", EP",
#     "catno": "LIP004",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/17282449",
#     "title": "Spektrum",
#     "id": 17282449,
#     "year": 2021,
#     "artist": "Various"
# }
# Rating Info:
# {
#     "count": 20,
#     "average": 4.75
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\", W/Lbl, Sta",
#     "catno": "LIP005",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/23819831",
#     "title": "Piano Phase",
#     "id": 23819831,
#     "year": 2022,
#     "artist": "Ferdinger"
# }
# Rating Info:
# {
#     "count": 17,
#     "average": 4.88
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "4xFile, WAV, EP",
#     "catno": "LIP005",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/23824595",
#     "title": "Piano Phase",
#     "id": 23824595,
#     "year": 2022,
#     "artist": "Ferdinger"
# }
# Rating Info:
# {
#     "count": 1,
#     "average": 5.0
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\", W/Lbl",
#     "catno": "LIP006",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/24753029",
#     "title": "Calm & Quiet",
#     "id": 24753029,
#     "year": 2022,
#     "artist": "DJ Physical"
# }
# Rating Info:
# {
#     "count": 13,
#     "average": 4.77
# }

# %%
# Create specific output with changed URL
output_list = []
for release in unique_matching_list:
    new_dict = {
        "catno": release["release_info"]["catno"],
        "artist": release["release_info"]["artist"],
        "title": release["release_info"]["title"],
        "year": release["release_info"]["year"],
        "format": release["release_info"]["format"],
        "url": "https://www.discogs.com/es/release/{}".format(release["release_info"]["id"]),
        "rating": release["rating_info"]
    }
    output_list.append(new_dict)

# print(output_list)
print(json.dumps(output_list, indent=4))
# Out:
# [
#     {
#         "catno": "LIP003",
#         "artist": "Ferdinger",
#         "title": "Euphoria",
#         "year": 2020,
#         "format": "12\", EP",
#         "url": "https://www.discogs.com/es/release/14704507",
#         "rating": {
#             "count": 14,
#             "average": 4.79
#         }
#     },
#     {
#         "catno": "LIP004",
#         "artist": "Various",
#         "title": "Spektrum",
#         "year": 2021,
#         "format": "12\", EP",
#         "url": "https://www.discogs.com/es/release/17282449",
#         "rating": {
#             "count": 20,
#             "average": 4.75
#         }
#     },
#     {
#         "catno": "LIP005",
#         "artist": "Ferdinger",
#         "title": "Piano Phase",
#         "year": 2022,
#         "format": "12\", W/Lbl, Sta",
#         "url": "https://www.discogs.com/es/release/23819831",
#         "rating": {
#             "count": 17,
#             "average": 4.88
#         }
#     },
#     {
#         "catno": "LIP005",
#         "artist": "Ferdinger",
#         "title": "Piano Phase",
#         "year": 2022,
#         "format": "4xFile, WAV, EP",
#         "url": "https://www.discogs.com/es/release/23824595",
#         "rating": {
#             "count": 1,
#             "average": 5.0
#         }
#     },
#     {
#         "catno": "LIP006",
#         "artist": "DJ Physical",
#         "title": "Calm & Quiet",
#         "year": 2022,
#         "format": "12\", W/Lbl",
#         "url": "https://www.discogs.com/es/release/24753029",
#         "rating": {
#             "count": 13,
#             "average": 4.77
#         }
#     }
# ]
