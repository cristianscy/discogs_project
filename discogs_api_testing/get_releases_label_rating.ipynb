# %%
import json
import requests
import requests_cache 
from ratelimit import limits, sleep_and_retry

requests_cache.install_cache(cache_name='discogs_cache', backend='sqlite', expire_after=86400)

# Input variables
label_id = "771357"
min_average = 4.7

# %%
# Define function to limit API call rate
# 25 calls per minute
CALLS = 25
RATE_LIMIT = 60

@sleep_and_retry
@limits(calls=CALLS, period=RATE_LIMIT)
def check_limit():
    ''' Empty function just to check for calls to API '''
    return

# %%
# Define function to get label's releases recursively
def get_label_recursively(label_id, page, all_releases=None):
    # Variables
    label_url = "https://api.discogs.com/labels/{}/releases?page={}&per_page=25".format(label_id, page)

    # Initialize all_releases if not provided
    if all_releases is None:
        all_releases = {"pagination": {"page": 0, "pages": 0, "per_page": 25, "items": 0}, "releases": []}

    # Make the HTTP request
    check_limit()
    response = requests.get(label_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        response_dict = response.json()

        # Print the formatted JSON
        # print(json.dumps(response_dict, indent=4))

        # Add releases to the aggregate dictionary
        all_releases["releases"].extend(response_dict["releases"])
        all_releases["pagination"] = response_dict["pagination"]

        # Check if there are more pages to fetch
        next_page = response_dict["pagination"]["urls"].get("next")
        if next_page:
            # Recursively call the function for the next page
            get_label_recursively(label_id, page + 1, all_releases)

    else:
        # Print an error message if the request was not successful
        print(f"Error: Unable to fetch data. Status code: {response.status_code}")

    return all_releases

# Define function to get community release rating
def get_rating(release_url):

    # Variables
    rating_url = release_url + "/rating"
    
    # Make the HTTP request
    check_limit()
    response = requests.get(rating_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the JSON response
        response_dict = response.json()

        # Print the formatted JSON
        # print(json.dumps(response_dict, indent=4))

        # Return value
        return response_dict
    else:
        # Print an error message if the request was not successful
        print(f"Error: Unable to fetch data. Status code: {response.status_code}")

# Define function to remove duplicates from an input_list and key_path
def remove_duplicates(input_list, key_path):
    unique_list = []
    seen_ids = set()

    for item in input_list:
        item_id = get_nested_value(item, key_path)
        if item_id not in seen_ids:
            seen_ids.add(item_id)
            unique_list.append(item)

    return unique_list

# Handle nested keys
def get_nested_value(dictionary, key_path):
    current_value = dictionary
    for key in key_path:
        current_value = current_value.get(key, {})
    return current_value

# Define function to match releases with filtered_rating_list
def create_matching_releases(response_dict, filtered_rating_list):
    # Create a dictionary mapping release_id to rating_info
    rating_info_dict = {item["release_id"]: item["rating"] for item in filtered_rating_list}

    # # Debug
    # print("##### DEBUG #####")
    # print(type(rating_info_dict))
    # print(json.dumps(rating_info_dict, indent=4))

    # Extract information from response_dict only for matching release_ids
    matching_releases = [
        {
            "release_info": release_info,
            "rating_info": rating_info_dict.get(release_info["id"])
        }
        for release_info in response_dict["releases"] if release_info["id"] in rating_info_dict
    ]

    # # Debug
    # print("##### DEBUG #####")
    # print(type(matching_releases))
    # for item in matching_releases:
    #     print(json.dumps(item, indent=4))

    return matching_releases

# Define function to create output list
def create_output_list(unique_matching_list):
    output_list = []

    for release in unique_matching_list:
        new_dict = {
            "catno": release["release_info"]["catno"],
            "artist": release["release_info"]["artist"],
            "title": release["release_info"]["title"],
            "year": release["release_info"]["year"],
            "format": release["release_info"]["format"],
            "url": "https://www.discogs.com/es/release/{}".format(release["release_info"]["id"]),
            "rating": release["rating_info"]
        }
        output_list.append(new_dict)

    return output_list

# %%
# Call get_label function for first time
# response_label_dict = get_label(label_id,1)
# print()
# print(type(response_dict))

# Call get_label_recursively function
response_label_dict = get_label_recursively(label_id,1)

# Debug
print("##### DEBUG #####")
print(type(response_label_dict))
print(json.dumps(response_label_dict, indent=4))
# Out:
# ##### DEBUG #####
# <class 'dict'>
# {
#     "pagination": {
#         "page": 6,
#         "pages": 6,
#         "per_page": 25,
#         "items": 137,
#         "urls": {
#             "first": "https://api.discogs.com/labels/771357/releases?page=1&per_page=25",
#             "prev": "https://api.discogs.com/labels/771357/releases?page=5&per_page=25"
#         }
#     },
#     "releases": [
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP006",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8544555",
#             "title": "When I Was 14",
#             "id": 8544555,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP006",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8544555",
#             "title": "When I Was 14",
#             "id": 8544555,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP032, trip 32",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15781803",
#             "title": "Pornographic Novel",
#             "id": 15781803,
#             "year": 2020,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP032, trip 32",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15781803",
#             "title": "Pornographic Novel",
#             "id": 15781803,
#             "year": 2020,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP022",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12957162",
#             "title": "Cheerful Pessimist ",
#             "id": 12957162,
#             "year": 2018,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP022",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12957162",
#             "title": "Cheerful Pessimist ",
#             "id": 12957162,
#             "year": 2018,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "CD, Comp",
#             "catno": "GROOVE 158 / CD 67",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7865479",
#             "title": "Groove 158 / CD 67",
#             "id": 7865479,
#             "year": 2015,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "CD, Comp",
#             "catno": "GROOVE 158 / CD 67",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7865479",
#             "title": "Groove 158 / CD 67",
#             "id": 7865479,
#             "year": 2015,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRPT01",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/27097950",
#             "title": "The Feeling",
#             "id": 27097950,
#             "year": 0,
#             "artist": "Frantic 18"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRPT01",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/27097950",
#             "title": "The Feeling",
#             "id": 27097950,
#             "year": 0,
#             "artist": "Frantic 18"
#         },
#         {
#             "status": "Accepted",
#             "format": "CD, Comp",
#             "catno": "GROOVE 162 / CD 71",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8922665",
#             "title": "Groove 162 / CD 71",
#             "id": 8922665,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP012",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10123074",
#             "title": "A Broken Clock Is Right Twice A Day",
#             "id": 10123074,
#             "year": 2017,
#             "artist": "PTU"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP012",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10123074",
#             "title": "A Broken Clock Is Right Twice A Day",
#             "id": 10123074,
#             "year": 2017,
#             "artist": "PTU"
#         },
#         {
#             "status": "Accepted",
#             "format": "CD, Comp",
#             "catno": "GROOVE 162 / CD 71",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8922665",
#             "title": "Groove 162 / CD 71",
#             "id": 8922665,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "197188406875",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/27081873",
#             "title": "White Horse",
#             "id": 27081873,
#             "year": 2023,
#             "artist": "Nina Kraviz, Indira Paganotto"
#         },
#         {
#             "status": "Accepted",
#             "format": "3xFile, FLAC, EP",
#             "catno": "none",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15415420",
#             "title": "Stranno Neobjatno",
#             "id": 15415420,
#             "year": 2019,
#             "artist": "Nina Kraviz"
#         },
#         {
#             "status": "Accepted",
#             "format": "2xFile, FLAC, EP",
#             "catno": "none",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/27244578",
#             "title": "Fresh Jive",
#             "id": 27244578,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, FLAC, EP",
#             "catno": "none",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/23474363",
#             "title": "The Botox Queen",
#             "id": 23474363,
#             "year": 2022,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP019, trip 19",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11281777",
#             "title": "\u041f\u0430\u0440\u0430\u0434\u043e\u043a\u0441 = Paradox",
#             "id": 11281777,
#             "year": 2017,
#             "artist": "Aleksi Per\u00e4l\u00e4"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP028, trip 28",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14459372",
#             "title": "\u0420\u0435\u0437\u043e\u043d\u0430\u043d\u0441 = Resonance",
#             "id": 14459372,
#             "year": 2019,
#             "artist": "Aleksi Per\u00e4l\u00e4"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP030 , trip 30",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14541303",
#             "title": "\u0411\u0443\u0434\u043d\u0438 \u041d\u0430\u0448\u0435\u0433\u043e \u041a\u043e\u043b\u0445\u043e\u0437\u0430 = Budni Nashego Kolhoza",
#             "id": 14541303,
#             "year": 2019,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP032, trip 32",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15781803",
#             "title": "Pornographic Novel",
#             "id": 15781803,
#             "year": 2020,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP036, trip 36",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/19327852",
#             "title": "Stage Of Loyalty",
#             "id": 19327852,
#             "year": 2021,
#             "artist": "Roma Zuckerman"
#         },
#         {
#             "status": "Accepted",
#             "format": "2xFile, WAV",
#             "catno": "TRP 003",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/9518409",
#             "title": "\u0410\u0440\u0442\u0443\u0440 \u0418 \u0418\u043d\u0442\u0435\u0440\u0433\u0430\u043b\u0430\u043a\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u041a\u0438\u0442\u044b = Arthur And The Intergalactic Whales",
#             "id": 9518409,
#             "year": 2015,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "2xFile, FLAC",
#             "catno": "TRP 003",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/19957708",
#             "title": "\u0410\u0440\u0442\u0443\u0440 \u0418 \u0418\u043d\u0442\u0435\u0440\u0433\u0430\u043b\u0430\u043a\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u041a\u0438\u0442\u044b = Arthur And The Intergalactic Whales",
#             "id": 19957708,
#             "year": 2015,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "13xFile, WAV",
#             "catno": "TRP 007",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/9518451",
#             "title": "\"\u0411\" = \"B\"",
#             "id": 9518451,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "13xFile, FLAC, Album",
#             "catno": "TRP 007",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13280954",
#             "title": "\u0411 = B ",
#             "id": 13280954,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "10xFile, FLAC, Album",
#             "catno": "TRP 028",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14497194",
#             "title": "Resonance",
#             "id": 14497194,
#             "year": 2019,
#             "artist": "Aleksi Per\u00e4l\u00e4"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", S/Sided, Ltd, W/Lbl, Cle",
#             "catno": "TRP ADE PT 1",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11025064",
#             "title": "TRP ADE PT 1",
#             "id": 11025064,
#             "year": 2017,
#             "artist": "Nina Kraviz"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", Ltd, W/Lbl, Whi",
#             "catno": "TRP ADE PT 2",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11030583",
#             "title": "TRP ADE PT 2",
#             "id": 11030583,
#             "year": 2017,
#             "artist": "Bjarki +  Nina Kraviz"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", Ltd, S/Edition, W/Lbl, Cle",
#             "catno": "TRP ADE PT 3",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11030620",
#             "title": "TRP ADE PT 3",
#             "id": 11030620,
#             "year": 2017,
#             "artist": "DJ Rush / K-Hand*"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", Comp, TP, W/Lbl",
#             "catno": "TRP001",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/18530437",
#             "title": "\u0412\u0434\u0440\u0443\u0433 \u041f\u043e\u044f\u0432\u0438\u043b\u0441\u044f \u041e\u0441\u044c\u043c\u0438\u043d\u043e\u0433 \u0418 \u0412\u0441\u0435\u0445 \u0421\u044a\u0435\u043b \u0418 \u0420\u0430\u0437\u0434\u0443\u043c\u044b\u0432\u0430\u0442\u044c \u041d\u0435 \u0421\u0442\u0430\u043b = Without A Moment's Notice, An Octopus Appeared And Devoured Everyone In Sight",
#             "id": 18530437,
#             "year": 2014,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "8xFile, MP3, Comp",
#             "catno": "TRP001",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/6420111",
#             "title": "\u0412\u0434\u0440\u0443\u0433 \u041f\u043e\u044f\u0432\u0438\u043b\u0441\u044f \u041e\u0441\u044c\u043c\u0438\u043d\u043e\u0433 \u0418 \u0412\u0441\u0435\u0445 \u0421\u044a\u0435\u043b \u0418 \u0420\u0430\u0437\u0434\u0443\u043c\u044b\u0432\u0430\u0442\u044c \u041d\u0435 \u0421\u0442\u0430\u043b ",
#             "id": 6420111,
#             "year": 2014,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp, Gat",
#             "catno": "TRP001",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/6374407",
#             "title": "\u0412\u0434\u0440\u0443\u0433 \u041f\u043e\u044f\u0432\u0438\u043b\u0441\u044f \u041e\u0441\u044c\u043c\u0438\u043d\u043e\u0433 \u0418 \u0412\u0441\u0435\u0445 \u0421\u044a\u0435\u043b \u0418 \u0420\u0430\u0437\u0434\u0443\u043c\u044b\u0432\u0430\u0442\u044c \u041d\u0435 \u0421\u0442\u0430\u043b = Without A Moment's Notice, An Octopus Appeared And Devoured Everyone In Sight",
#             "id": 6374407,
#             "year": 2014,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "8xFile, FLAC, Comp",
#             "catno": "TRP001",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/6435312",
#             "title": "The Deviant Octopus",
#             "id": 6435312,
#             "year": 2014,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp, RP",
#             "catno": "TRP001",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/20147875",
#             "title": "\u0412\u0434\u0440\u0443\u0433 \u041f\u043e\u044f\u0432\u0438\u043b\u0441\u044f \u041e\u0441\u044c\u043c\u0438\u043d\u043e\u0433 \u0418 \u0412\u0441\u0435\u0445 \u0421\u044a\u0435\u043b \u0418 \u0420\u0430\u0437\u0434\u0443\u043c\u044b\u0432\u0430\u0442\u044c \u041d\u0435 \u0421\u0442\u0430\u043b = Without A Moment's Notice, An Octopus Appeared And Devoured Everyone In Sight",
#             "id": 20147875,
#             "year": 2021,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP002",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7028597",
#             "title": "De Niro Is Concerned",
#             "id": 7028597,
#             "year": 2015,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp, RP",
#             "catno": "TRP002",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/20481352",
#             "title": "De Niro Is Concerned",
#             "id": 20481352,
#             "year": 2021,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "7xFile, MP3, Comp",
#             "catno": "TRP002",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7077894",
#             "title": " \u0414\u0435 \u041d\u0438\u0440\u043e \u0420\u0430\u0437\u0432\u043e\u043b\u043d\u043e\u0432\u0430\u043b\u0441\u044f, \u041f\u0440\u043e\u0441\u043d\u0443\u043b\u0441\u044f \u041f\u043e\u0441\u0440\u0435\u0434\u0438 \u041d\u043e\u0447\u0438 \u0412 \u0425\u043e\u043b\u043e\u0434\u043d\u043e\u043c \u041f\u043e\u0442\u0443, \u041f\u043e\u0434\u0443\u043c\u0430\u043b: \"\u041a\u0430\u043a \u0416\u0435 \u0422\u0430\u043a \u0412\u044b\u0448\u043b\u043e, \u0420\u043e\u0431\u0435\u0440\u0442?\" \u041f\u043e\u0431\u0440\u043e\u0441\u0430\u043b \u0412\u0441\u0435 \u0412 \u0427\u0435\u043c\u043e\u0434\u0430\u043d \u0418 \u041f\u0440\u043e\u0447\u044c \u0421 \u0413\u043e\u043b\u043b\u0438\u0432\u0443\u0434",
#             "id": 7077894,
#             "year": 2015,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2xFile, MP3, 320",
#             "catno": "TRP003",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7289098",
#             "title": "\u0410\u0440\u0442\u0443\u0440 \u0418 \u0418\u043d\u0442\u0435\u0440\u0433\u0430\u043b\u0430\u043a\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u041a\u0438\u0442\u044b = Arthur And The Intergalactic Whales",
#             "id": 7289098,
#             "year": 2015,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP003",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7213688",
#             "title": "\u0410\u0440\u0442\u0443\u0440 \u0418 \u0418\u043d\u0442\u0435\u0440\u0433\u0430\u043b\u0430\u043a\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u041a\u0438\u0442\u044b = Arthur And Intergalactic Whales",
#             "id": 7213688,
#             "year": 2015,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", RP",
#             "catno": "TRP003",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/20481418",
#             "title": "\u0410\u0440\u0442\u0443\u0440 \u0418 \u0418\u043d\u0442\u0435\u0440\u0433\u0430\u043b\u0430\u043a\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0435 \u041a\u0438\u0442\u044b = Arthur And Intergalactic Whales",
#             "id": 20481418,
#             "year": 2021,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP004",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7721779",
#             "title": "\u0418\u0432\u0430\u043d, \u0414\u0430\u0432\u0430\u0439! \u041e\u0442\u043a\u0440\u043e\u0439 \u041a\u043e\u0440\u043e\u0431\u043a\u0443! = Ivan, Come On, Unlock The Box ",
#             "id": 7721779,
#             "year": 2015,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "6xFile, MP3, Comp, 320",
#             "catno": "TRP004",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7943811",
#             "title": "Ivan, Come On, Unlock The Box ",
#             "id": 7943811,
#             "year": 2015,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp, RP",
#             "catno": "TRP004",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/21454171",
#             "title": "\u0418\u0432\u0430\u043d, \u0414\u0430\u0432\u0430\u0439! \u041e\u0442\u043a\u0440\u043e\u0439 \u041a\u043e\u0440\u043e\u0431\u043a\u0443! = Ivan, Come On, Unlock The Box ",
#             "id": 21454171,
#             "year": 2021,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP005",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7805062",
#             "title": "\u0423 \u041c\u0435\u043d\u044f \u0415\u0441\u0442\u044c \u0412\u043e\u043f\u0440\u043e\u0441 = I Have A Question",
#             "id": 7805062,
#             "year": 2015,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp, RP",
#             "catno": "TRP005",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/21459289",
#             "title": "\u0423 \u041c\u0435\u043d\u044f \u0415\u0441\u0442\u044c \u0412\u043e\u043f\u0440\u043e\u0441 = I Have A Question",
#             "id": 21459289,
#             "year": 2021,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "8xFile, MP3, Comp,  32",
#             "catno": "TRP005",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/7972136",
#             "title": "\u0423 \u041c\u0435\u043d\u044f \u0415\u0441\u0442\u044c \u0412\u043e\u043f\u0440\u043e\u0441 = I Have A Question",
#             "id": 7972136,
#             "year": 2015,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP006",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8544555",
#             "title": "When I Was 14",
#             "id": 8544555,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "6xFile, MP3, Comp, 320",
#             "catno": "TRP006",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8546102",
#             "title": "When I Was 14",
#             "id": 8546102,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "6xFile, FLAC, Comp",
#             "catno": "TRP006",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8603454",
#             "title": "When I Was 14",
#             "id": 8603454,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "3x12\", Album",
#             "catno": "TRP007",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8658694",
#             "title": "\u0411 = B",
#             "id": 8658694,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp, RP",
#             "catno": "TRP008",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/25296820",
#             "title": "\u0421\u043e\u043d \u041d\u0435 \u0414\u043b\u044f \u041c\u0435\u043d\u044f",
#             "id": 25296820,
#             "year": 2022,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "7xFile, FLAC, Comp",
#             "catno": "TRP008",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/9020115",
#             "title": "\u0421\u043e\u043d \u041d\u0435 \u0414\u043b\u044f \u041c\u0435\u043d\u044f",
#             "id": 9020115,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP008",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/8800052",
#             "title": "\u0421\u043e\u043d \u041d\u0435 \u0414\u043b\u044f \u041c\u0435\u043d\u044f",
#             "id": 8800052,
#             "year": 2016,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "3x12\", Album",
#             "catno": "TRP009",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/9081991",
#             "title": "Lefhanded Fuqs",
#             "id": 9081991,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12xFile, FLAC, Album",
#             "catno": "TRP009",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13281059",
#             "title": "Lefhanded Fuqs",
#             "id": 13281059,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12xFile, MP3, Album, 320",
#             "catno": "TRP009",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11442221",
#             "title": "Lefhanded Fuqs",
#             "id": 11442221,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12xFile, FLAC, Album",
#             "catno": "TRP010",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13281047",
#             "title": "\"\u00c6\"",
#             "id": 13281047,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "3x12\", Album",
#             "catno": "TRP010",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/9268387",
#             "title": "\"\u00c6\"",
#             "id": 9268387,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12xFile, MP3, Album, 320",
#             "catno": "TRP010",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13235137",
#             "title": "\u00c6",
#             "id": 13235137,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP011",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/9445368",
#             "title": " \u0421\u0432\u0435\u0436\u0438\u0439 \u0414\u0436\u0430\u0439\u0432 = Fresh Jive",
#             "id": 9445368,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP, TP, W/Lbl, 140",
#             "catno": "TRP011",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/18370783",
#             "title": " \u0421\u0432\u0435\u0436\u0438\u0439 \u0414\u0436\u0430\u0439\u0432 = Fresh Jive",
#             "id": 18370783,
#             "year": 2016,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP012",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10123074",
#             "title": "A Broken Clock Is Right Twice A Day",
#             "id": 10123074,
#             "year": 2017,
#             "artist": "PTU"
#         },
#         {
#             "status": "Accepted",
#             "format": "13xFile, MP3, Album, 320",
#             "catno": "TRP013",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12044565",
#             "title": "Halogen Continues",
#             "id": 12044565,
#             "year": 2017,
#             "artist": "Biogen"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP013",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10477649",
#             "title": "Halogen Continues",
#             "id": 10477649,
#             "year": 2017,
#             "artist": "Biogen"
#         },
#         {
#             "status": "Accepted",
#             "format": "3xFile, AAC, AIFF, ALAC, FLAC, MP3, ogg, WAV, EP",
#             "catno": "TRP014",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11024821",
#             "title": "Pochuvstvui",
#             "id": 11024821,
#             "year": 2017,
#             "artist": "Nina Kraviz"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP014",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10536213",
#             "title": "Pochuvstvui",
#             "id": 10536213,
#             "year": 2017,
#             "artist": "Nina Kraviz"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, MP3, EP, 320",
#             "catno": "TRP015",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/22842263",
#             "title": "This 5321",
#             "id": 22842263,
#             "year": 2022,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP015",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10689824",
#             "title": "This 5321",
#             "id": 10689824,
#             "year": 2017,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", EP",
#             "catno": "TRP016",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/10945046",
#             "title": "\u043c\u0435\u043d\u0434\u043e\u0437\u0430 = Mendoza",
#             "id": 10945046,
#             "year": 2017,
#             "artist": "Deniro (5)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP017",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11143870",
#             "title": "Hessdalen",
#             "id": 11143870,
#             "year": 2017,
#             "artist": "Volruptus"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, FLAC, EP",
#             "catno": "TRP017",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/22484837",
#             "title": "Hessdalen EP",
#             "id": 22484837,
#             "year": 2017,
#             "artist": "Volruptus"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", RP",
#             "catno": "TRP017",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26056036",
#             "title": "Hessdalen",
#             "id": 26056036,
#             "year": 2022,
#             "artist": "Volruptus"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", RP",
#             "catno": "TRP018",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/25297117",
#             "title": "That Present Terminal",
#             "id": 25297117,
#             "year": 2022,
#             "artist": "Roma Zuckerman"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP018",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11258282",
#             "title": "That Present Terminal",
#             "id": 11258282,
#             "year": 2017,
#             "artist": "Roma Zuckerman"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\"",
#             "catno": "TRP019",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/22088110",
#             "title": "Paradox",
#             "id": 22088110,
#             "year": 2022,
#             "artist": "Aleksi Per\u00e4l\u00e4"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP019, trip 19",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11281777",
#             "title": "\u041f\u0430\u0440\u0430\u0434\u043e\u043a\u0441 = Paradox",
#             "id": 11281777,
#             "year": 2017,
#             "artist": "Aleksi Per\u00e4l\u00e4"
#         },
#         {
#             "status": "Accepted",
#             "format": "10xFile, FLAC, Album",
#             "catno": "TRP019",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/11299154",
#             "title": "Paradox",
#             "id": 11299154,
#             "year": 2017,
#             "artist": "Aleksi Per\u00e4l\u00e4"
#         },
#         {
#             "status": "Accepted",
#             "format": "10xFile, FLAC, Comp",
#             "catno": "TRP020",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/22650743",
#             "title": "Don't Mess With Cupid, 'Cause Cupid Ain't Stupid",
#             "id": 22650743,
#             "year": 2018,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP020",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12252717",
#             "title": "Don't Mess With Cupid, 'Cause Cupid Ain't Stupid",
#             "id": 12252717,
#             "year": 2018,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "10xFile, MP3, Comp, 320",
#             "catno": "TRP020",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12376575",
#             "title": "Don't Mess With Cupid, 'Cause Cupid Ain't Stupid",
#             "id": 12376575,
#             "year": 2018,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP021",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12294503",
#             "title": "Oli Gumm",
#             "id": 12294503,
#             "year": 2018,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, FLAC, EP",
#             "catno": "TRP021",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13280618",
#             "title": "Oli Gumm",
#             "id": 13280618,
#             "year": 2018,
#             "artist": "Bjarki"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, FLAC, EP",
#             "catno": "TRP022",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12956894",
#             "title": "Cheerful Pessimist ",
#             "id": 12956894,
#             "year": 2018,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP022",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12957162",
#             "title": "Cheerful Pessimist ",
#             "id": 12957162,
#             "year": 2018,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP023, \u0442\u0440\u0438\u043f \u0434\u0432\u0430\u0434\u0446\u0430\u0442\u044c \u0442\u0440\u0435\u0442\u0438\u0439",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12999413",
#             "title": "\u0421 \u041d\u043e\u0432\u044b\u043c \u0413\u043e\u0434\u043e\u043c! \u041c\u044b \u0416\u0435\u043b\u0430\u0435\u043c \u0421\u0447\u0430\u0441\u0442\u044c\u044f \u0412\u0430\u043c! = Happy New Year! We Wish You Happiness!",
#             "id": 12999413,
#             "year": 2018,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "12xFile, FLAC",
#             "catno": "TRP024",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14134549",
#             "title": "Am I Who I Am",
#             "id": 14134549,
#             "year": 2019,
#             "artist": "PTU"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album, Promo, W/Lbl",
#             "catno": "TRP024",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/18378958",
#             "title": "Am I Who I Am",
#             "id": 18378958,
#             "year": 2019,
#             "artist": "PTU"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP024",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13717689",
#             "title": "Am I Who I Am",
#             "id": 13717689,
#             "year": 2019,
#             "artist": "PTU"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP025",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13915901",
#             "title": "Stranno Neobjatno",
#             "id": 13915901,
#             "year": 2019,
#             "artist": "Nina Kraviz"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP026",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/13982278",
#             "title": "Nikolai Reptile",
#             "id": 13982278,
#             "year": 2019,
#             "artist": "Shadowax"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP028, trip 28",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14459372",
#             "title": "\u0420\u0435\u0437\u043e\u043d\u0430\u043d\u0441 = Resonance",
#             "id": 14459372,
#             "year": 2019,
#             "artist": "Aleksi Per\u00e4l\u00e4"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Comp",
#             "catno": "TRP029",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14703483",
#             "title": "Locus Error",
#             "id": 14703483,
#             "year": 2020,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP030 , trip 30",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14541303",
#             "title": "\u0411\u0443\u0434\u043d\u0438 \u041d\u0430\u0448\u0435\u0433\u043e \u041a\u043e\u043b\u0445\u043e\u0437\u0430 = Budni Nashego Kolhoza",
#             "id": 14541303,
#             "year": 2019,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, MP3, EP, 320",
#             "catno": "TRP030 ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/14984935",
#             "title": "Budni Nashego Kolhoza",
#             "id": 14984935,
#             "year": 2019,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "5xFile, AIFF",
#             "catno": "TRP030 ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/28520992",
#             "title": "Budni Nashego Kolhoza",
#             "id": 28520992,
#             "year": 2019,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP031",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15724170",
#             "title": "The Bow",
#             "id": 15724170,
#             "year": 2020,
#             "artist": "Carlota (3)"
#         },
#         {
#             "status": "Accepted",
#             "format": "6xFile, FLAC, EP",
#             "catno": "TRP031",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15762698",
#             "title": "The Bow",
#             "id": 15762698,
#             "year": 2020,
#             "artist": "Carlota (3)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP, TP",
#             "catno": "TRP031",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/22407970",
#             "title": "The Bow",
#             "id": 22407970,
#             "year": 2020,
#             "artist": "Carlota (3)"
#         },
#         {
#             "status": "Accepted",
#             "format": "6xFile, FLAC, EP",
#             "catno": "TRP032",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/16039145",
#             "title": "Pornographic Novel",
#             "id": 16039145,
#             "year": 2020,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "6xFile, MP3, EP, 320",
#             "catno": "TRP032",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15906160",
#             "title": "Pornographic Novel",
#             "id": 15906160,
#             "year": 2020,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP032, trip 32",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15781803",
#             "title": "Pornographic Novel",
#             "id": 15781803,
#             "year": 2020,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP032S ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558294",
#             "title": "Russian Porn Magazine",
#             "id": 26558294,
#             "year": 2020,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP033",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/16917993",
#             "title": "Coachella",
#             "id": 16917993,
#             "year": 2021,
#             "artist": "Deniro (5)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", TP, W/Lbl",
#             "catno": "TRP033",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/18450988",
#             "title": "Coachella",
#             "id": 18450988,
#             "year": 2021,
#             "artist": "Deniro (5)"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP033S ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558285",
#             "title": "Boss 303",
#             "id": 26558285,
#             "year": 2020,
#             "artist": "Deniro (5)"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", TP, W/Lbl",
#             "catno": "TRP034",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/20192506",
#             "title": "Thought Dealer",
#             "id": 20192506,
#             "year": 2021,
#             "artist": "AADJA"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRP034",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/16917921",
#             "title": "Thought Dealer",
#             "id": 16917921,
#             "year": 2021,
#             "artist": "AADJA"
#         },
#         {
#             "status": "Accepted",
#             "format": "13xFile, MP3, Album, 320",
#             "catno": "TRP035",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/19605109",
#             "title": "Green Trax",
#             "id": 19605109,
#             "year": 2021,
#             "artist": "Steve O'Sullivan"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP035",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/18019900",
#             "title": "Green Trax",
#             "id": 18019900,
#             "year": 2021,
#             "artist": "Steve O'Sullivan"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP035S ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558246",
#             "title": "Berdea",
#             "id": 26558246,
#             "year": 2021,
#             "artist": "Steve O'Sullivan"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP036, trip 36",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/19327852",
#             "title": "Stage Of Loyalty",
#             "id": 19327852,
#             "year": 2021,
#             "artist": "Roma Zuckerman"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP036S1 ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558276",
#             "title": "I Like You",
#             "id": 26558276,
#             "year": 2021,
#             "artist": "Roma Zuckerman"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP036S2 ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558261",
#             "title": "Frequency Hole 4",
#             "id": 26558261,
#             "year": 2021,
#             "artist": "Roma Zuckerman"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\"",
#             "catno": "TRP037",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/23100734",
#             "title": "Iteritax",
#             "id": 23100734,
#             "year": 2022,
#             "artist": "Cerrot"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP037S1 ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558231",
#             "title": "Iteritax",
#             "id": 26558231,
#             "year": 2021,
#             "artist": "Cerrot"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP037S2",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558219",
#             "title": "Left And Right",
#             "id": 26558219,
#             "year": 2022,
#             "artist": "Cerrot"
#         },
#         {
#             "status": "Accepted",
#             "format": "2xLP",
#             "catno": "TRP038",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/25237951",
#             "title": "All His Decisions",
#             "id": 25237951,
#             "year": 2022,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "11xFile, MP3, Comp, 320",
#             "catno": "TRP038",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/23223176",
#             "title": "All His Decisions",
#             "id": 23223176,
#             "year": 2022,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP038S2",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558207",
#             "title": "Atom Heart",
#             "id": 26558207,
#             "year": 2022,
#             "artist": "u.r.trax"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", EP",
#             "catno": "TRP039",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/24645107",
#             "title": "The Botox Queen",
#             "id": 24645107,
#             "year": 2022,
#             "artist": "Vladimir Dubyshkin"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", Album",
#             "catno": "TRP040",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/25352761",
#             "title": "Third Ear",
#             "id": 25352761,
#             "year": 2022,
#             "artist": "u.r.trax"
#         },
#         {
#             "status": "Accepted",
#             "format": "9xFile, WAV, Album",
#             "catno": "TRP040",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/25352788",
#             "title": "Third Ear",
#             "id": 25352788,
#             "year": 2022,
#             "artist": "u.r.trax"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP040S1 ",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/26558192",
#             "title": "Biosseum",
#             "id": 26558192,
#             "year": 2022,
#             "artist": "u.r.trax"
#         },
#         {
#             "status": "Accepted",
#             "format": "6xFile, WAV, EP",
#             "catno": "TRP041",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/25276819",
#             "title": "Always",
#             "id": 25276819,
#             "year": 2022,
#             "artist": "Alex Wilcox"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", Maxi",
#             "catno": "TRP041",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/28501180",
#             "title": "Always",
#             "id": 28501180,
#             "year": 2023,
#             "artist": "Alex Wilcox"
#         },
#         {
#             "status": "Accepted",
#             "format": "File, MP3, 320",
#             "catno": "TRP042S1",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/25413871",
#             "title": "Hace Ejercicios",
#             "id": 25413871,
#             "year": 2022,
#             "artist": "Nina Kraviz"
#         },
#         {
#             "status": "Accepted",
#             "format": "16xFile, WAV, Album",
#             "catno": "TRP045",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/27246489",
#             "title": "137",
#             "id": 27246489,
#             "year": 2023,
#             "artist": "Soren Jahan"
#         },
#         {
#             "status": "Accepted",
#             "format": "LP",
#             "catno": "TRP045",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/29146294",
#             "title": "137",
#             "id": 29146294,
#             "year": 2023,
#             "artist": "Soren Jahan"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", W/Lbl",
#             "catno": "Trpade2018pt1",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12703540",
#             "title": "Trip ADE 2018 PT1",
#             "id": 12703540,
#             "year": 2018,
#             "artist": "Roma Zuckerman"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", Ltd, W/Lbl",
#             "catno": "Trpade2018pt2",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12689487",
#             "title": "TRP ADE 2018 PT2",
#             "id": 12689487,
#             "year": 2018,
#             "artist": "Nina Kraviz"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\", Ltd, W/Lbl",
#             "catno": "Trpade2018pt3",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12693174",
#             "title": "Trip ADE 2018 PT3",
#             "id": 12693174,
#             "year": 2018,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "21xFile, MP3, Comp, 320",
#             "catno": "TRPHS001",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/15536429",
#             "title": "Hot Steel",
#             "id": 15536429,
#             "year": 2020,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "21xFile, MP3, Comp, 320",
#             "catno": "TRPHS002",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/16347822",
#             "title": "Hot Steel: Round 2",
#             "id": 16347822,
#             "year": 2020,
#             "artist": "Various"
#         },
#         {
#             "status": "Accepted",
#             "format": "12\"",
#             "catno": "TRPT01",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/27097950",
#             "title": "The Feeling",
#             "id": 27097950,
#             "year": 0,
#             "artist": "Frantic 18"
#         },
#         {
#             "status": "Accepted",
#             "format": "2x12\", Album",
#             "catno": "TRP023, \u0442\u0440\u0438\u043f \u0434\u0432\u0430\u0434\u0446\u0430\u0442\u044c \u0442\u0440\u0435\u0442\u0438\u0439",
#             "thumb": "",
#             "resource_url": "https://api.discogs.com/releases/12999413",
#             "title": "\u0421 \u041d\u043e\u0432\u044b\u043c \u0413\u043e\u0434\u043e\u043c! \u041c\u044b \u0416\u0435\u043b\u0430\u0435\u043c \u0421\u0447\u0430\u0441\u0442\u044c\u044f \u0412\u0430\u043c! = Happy New Year! We Wish You Happiness!",
#             "id": 12999413,
#             "year": 2018,
#             "artist": "Various"
#         }
#     ]
# }

# %%
# Get community release rating
response_rating_list = []
for release in response_label_dict["releases"]:
    release_url = release["resource_url"]
    response_rating_dict = get_rating(release_url)
    response_rating_list.append(response_rating_dict) 

# Debug
print("##### DEBUG #####")
print("length response_rating_list: " + str(len(response_rating_list)))
for item in response_rating_list:
   print(item)
# Out:
# ##### DEBUG #####
# length response_rating_list: 137
# {'release_id': 8544555, 'rating': {'count': 105, 'average': 4.34}}
# {'release_id': 8544555, 'rating': {'count': 105, 'average': 4.34}}
# {'release_id': 15781803, 'rating': {'count': 82, 'average': 4.61}}
# {'release_id': 15781803, 'rating': {'count': 82, 'average': 4.61}}
# {'release_id': 12957162, 'rating': {'count': 117, 'average': 4.51}}
# {'release_id': 12957162, 'rating': {'count': 117, 'average': 4.51}}
# {'release_id': 7865479, 'rating': {'count': 17, 'average': 3.88}}
# {'release_id': 7865479, 'rating': {'count': 17, 'average': 3.88}}
# {'release_id': 27097950, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 27097950, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 8922665, 'rating': {'count': 15, 'average': 4.47}}
# {'release_id': 10123074, 'rating': {'count': 45, 'average': 4.27}}
# {'release_id': 10123074, 'rating': {'count': 45, 'average': 4.27}}
# {'release_id': 8922665, 'rating': {'count': 15, 'average': 4.47}}
# {'release_id': 27081873, 'rating': {'count': 4, 'average': 3.5}}
# {'release_id': 15415420, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 27244578, 'rating': {'count': 2, 'average': 3.5}}
# {'release_id': 23474363, 'rating': {'count': 5, 'average': 4.8}}
# {'release_id': 11281777, 'rating': {'count': 100, 'average': 4.82}}
# {'release_id': 14459372, 'rating': {'count': 54, 'average': 4.76}}
# {'release_id': 14541303, 'rating': {'count': 104, 'average': 4.52}}
# {'release_id': 15781803, 'rating': {'count': 82, 'average': 4.61}}
# {'release_id': 19327852, 'rating': {'count': 12, 'average': 4.17}}
# {'release_id': 9518409, 'rating': {'count': 4, 'average': 3.75}}
# {'release_id': 19957708, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 9518451, 'rating': {'count': 6, 'average': 3.33}}
# {'release_id': 13280954, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 14497194, 'rating': {'count': 3, 'average': 4.33}}
# {'release_id': 11025064, 'rating': {'count': 27, 'average': 4.3}}
# {'release_id': 11030583, 'rating': {'count': 36, 'average': 4.28}}
# {'release_id': 11030620, 'rating': {'count': 37, 'average': 4.84}}
# {'release_id': 18530437, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 6420111, 'rating': {'count': 5, 'average': 4.0}}
# {'release_id': 6374407, 'rating': {'count': 88, 'average': 4.44}}
# {'release_id': 6435312, 'rating': {'count': 7, 'average': 4.0}}
# {'release_id': 20147875, 'rating': {'count': 6, 'average': 4.33}}
# {'release_id': 7028597, 'rating': {'count': 82, 'average': 4.54}}
# {'release_id': 20481352, 'rating': {'count': 3, 'average': 5.0}}
# {'release_id': 7077894, 'rating': {'count': 6, 'average': 3.67}}
# {'release_id': 7289098, 'rating': {'count': 13, 'average': 3.46}}
# {'release_id': 7213688, 'rating': {'count': 185, 'average': 4.29}}
# {'release_id': 20481418, 'rating': {'count': 20, 'average': 4.3}}
# {'release_id': 7721779, 'rating': {'count': 36, 'average': 4.5}}
# {'release_id': 7943811, 'rating': {'count': 3, 'average': 3.33}}
# {'release_id': 21454171, 'rating': {'count': 4, 'average': 5.0}}
# {'release_id': 7805062, 'rating': {'count': 48, 'average': 4.42}}
# {'release_id': 21459289, 'rating': {'count': 3, 'average': 4.67}}
# {'release_id': 7972136, 'rating': {'count': 4, 'average': 3.75}}
# {'release_id': 8544555, 'rating': {'count': 105, 'average': 4.34}}
# {'release_id': 8546102, 'rating': {'count': 4, 'average': 3.75}}
# {'release_id': 8603454, 'rating': {'count': 2, 'average': 4.0}}
# {'release_id': 8658694, 'rating': {'count': 54, 'average': 4.41}}
# {'release_id': 25296820, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 9020115, 'rating': {'count': 5, 'average': 3.4}}
# {'release_id': 8800052, 'rating': {'count': 44, 'average': 4.45}}
# {'release_id': 9081991, 'rating': {'count': 40, 'average': 4.48}}
# {'release_id': 13281059, 'rating': {'count': 2, 'average': 3.5}}
# {'release_id': 11442221, 'rating': {'count': 4, 'average': 4.0}}
# {'release_id': 13281047, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 9268387, 'rating': {'count': 42, 'average': 4.4}}
# {'release_id': 13235137, 'rating': {'count': 1, 'average': 4.0}}
# {'release_id': 9445368, 'rating': {'count': 52, 'average': 4.37}}
# {'release_id': 18370783, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 10123074, 'rating': {'count': 45, 'average': 4.27}}
# {'release_id': 12044565, 'rating': {'count': 2, 'average': 4.5}}
# {'release_id': 10477649, 'rating': {'count': 33, 'average': 4.64}}
# {'release_id': 11024821, 'rating': {'count': 5, 'average': 2.2}}
# {'release_id': 10536213, 'rating': {'count': 70, 'average': 4.27}}
# {'release_id': 22842263, 'rating': {'count': 1, 'average': 3.0}}
# {'release_id': 10689824, 'rating': {'count': 73, 'average': 4.4}}
# {'release_id': 10945046, 'rating': {'count': 57, 'average': 4.49}}
# {'release_id': 11143870, 'rating': {'count': 77, 'average': 4.77}}
# {'release_id': 22484837, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 26056036, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 25297117, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 11258282, 'rating': {'count': 28, 'average': 4.68}}
# {'release_id': 22088110, 'rating': {'count': 5, 'average': 5.0}}
# {'release_id': 11281777, 'rating': {'count': 100, 'average': 4.82}}
# {'release_id': 11299154, 'rating': {'count': 5, 'average': 4.4}}
# {'release_id': 22650743, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 12252717, 'rating': {'count': 68, 'average': 4.46}}
# {'release_id': 12376575, 'rating': {'count': 5, 'average': 4.0}}
# {'release_id': 12294503, 'rating': {'count': 52, 'average': 4.29}}
# {'release_id': 13280618, 'rating': {'count': 3, 'average': 4.33}}
# {'release_id': 12956894, 'rating': {'count': 6, 'average': 4.5}}
# {'release_id': 12957162, 'rating': {'count': 117, 'average': 4.51}}
# {'release_id': 12999413, 'rating': {'count': 20, 'average': 4.45}}
# {'release_id': 14134549, 'rating': {'count': 1, 'average': 4.0}}
# {'release_id': 18378958, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 13717689, 'rating': {'count': 29, 'average': 4.52}}
# {'release_id': 13915901, 'rating': {'count': 64, 'average': 4.34}}
# {'release_id': 13982278, 'rating': {'count': 50, 'average': 4.68}}
# {'release_id': 14459372, 'rating': {'count': 54, 'average': 4.76}}
# {'release_id': 14703483, 'rating': {'count': 27, 'average': 4.7}}
# {'release_id': 14541303, 'rating': {'count': 104, 'average': 4.52}}
# {'release_id': 14984935, 'rating': {'count': 10, 'average': 4.2}}
# {'release_id': 28520992, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 15724170, 'rating': {'count': 21, 'average': 4.24}}
# {'release_id': 15762698, 'rating': {'count': 1, 'average': 4.0}}
# {'release_id': 22407970, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 16039145, 'rating': {'count': 2, 'average': 4.5}}
# {'release_id': 15906160, 'rating': {'count': 6, 'average': 4.33}}
# {'release_id': 15781803, 'rating': {'count': 82, 'average': 4.61}}
# {'release_id': 26558294, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 16917993, 'rating': {'count': 39, 'average': 4.51}}
# {'release_id': 18450988, 'rating': {'count': 1, 'average': 4.0}}
# {'release_id': 26558285, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 20192506, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 16917921, 'rating': {'count': 29, 'average': 4.38}}
# {'release_id': 19605109, 'rating': {'count': 4, 'average': 4.0}}
# {'release_id': 18019900, 'rating': {'count': 42, 'average': 4.76}}
# {'release_id': 26558246, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 19327852, 'rating': {'count': 12, 'average': 4.17}}
# {'release_id': 26558276, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 26558261, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 23100734, 'rating': {'count': 10, 'average': 4.8}}
# {'release_id': 26558231, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 26558219, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 25237951, 'rating': {'count': 5, 'average': 5.0}}
# {'release_id': 23223176, 'rating': {'count': 4, 'average': 2.5}}
# {'release_id': 26558207, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 24645107, 'rating': {'count': 24, 'average': 4.38}}
# {'release_id': 25352761, 'rating': {'count': 6, 'average': 3.5}}
# {'release_id': 25352788, 'rating': {'count': 4, 'average': 4.0}}
# {'release_id': 26558192, 'rating': {'count': 1, 'average': 1.0}}
# {'release_id': 25276819, 'rating': {'count': 3, 'average': 3.67}}
# {'release_id': 28501180, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 25413871, 'rating': {'count': 3, 'average': 2.0}}
# {'release_id': 27246489, 'rating': {'count': 2, 'average': 3.0}}
# {'release_id': 29146294, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 12703540, 'rating': {'count': 12, 'average': 5.0}}
# {'release_id': 12689487, 'rating': {'count': 30, 'average': 4.37}}
# {'release_id': 12693174, 'rating': {'count': 13, 'average': 4.77}}
# {'release_id': 15536429, 'rating': {'count': 10, 'average': 3.6}}
# {'release_id': 16347822, 'rating': {'count': 3, 'average': 2.67}}
# {'release_id': 27097950, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 12999413, 'rating': {'count': 20, 'average': 4.45}}

# %%
# Remove duplicates from "response_rating_list" based on "release_id" key
unique_rating_list = remove_duplicates(response_rating_list, ["release_id"])

# Debug
print("##### DEBUG #####")
print("length unique_rating_list: " + str(len(unique_rating_list)))
for item in unique_rating_list:
   print(item)
# Out:
# ##### DEBUG #####
# length unique_rating_list: 119
# {'release_id': 8544555, 'rating': {'count': 105, 'average': 4.34}}
# {'release_id': 15781803, 'rating': {'count': 82, 'average': 4.61}}
# {'release_id': 12957162, 'rating': {'count': 117, 'average': 4.51}}
# {'release_id': 7865479, 'rating': {'count': 17, 'average': 3.88}}
# {'release_id': 27097950, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 8922665, 'rating': {'count': 15, 'average': 4.47}}
# {'release_id': 10123074, 'rating': {'count': 45, 'average': 4.27}}
# {'release_id': 27081873, 'rating': {'count': 4, 'average': 3.5}}
# {'release_id': 15415420, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 27244578, 'rating': {'count': 2, 'average': 3.5}}
# {'release_id': 23474363, 'rating': {'count': 5, 'average': 4.8}}
# {'release_id': 11281777, 'rating': {'count': 100, 'average': 4.82}}
# {'release_id': 14459372, 'rating': {'count': 54, 'average': 4.76}}
# {'release_id': 14541303, 'rating': {'count': 104, 'average': 4.52}}
# {'release_id': 19327852, 'rating': {'count': 12, 'average': 4.17}}
# {'release_id': 9518409, 'rating': {'count': 4, 'average': 3.75}}
# {'release_id': 19957708, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 9518451, 'rating': {'count': 6, 'average': 3.33}}
# {'release_id': 13280954, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 14497194, 'rating': {'count': 3, 'average': 4.33}}
# {'release_id': 11025064, 'rating': {'count': 27, 'average': 4.3}}
# {'release_id': 11030583, 'rating': {'count': 36, 'average': 4.28}}
# {'release_id': 11030620, 'rating': {'count': 37, 'average': 4.84}}
# {'release_id': 18530437, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 6420111, 'rating': {'count': 5, 'average': 4.0}}
# {'release_id': 6374407, 'rating': {'count': 88, 'average': 4.44}}
# {'release_id': 6435312, 'rating': {'count': 7, 'average': 4.0}}
# {'release_id': 20147875, 'rating': {'count': 6, 'average': 4.33}}
# {'release_id': 7028597, 'rating': {'count': 82, 'average': 4.54}}
# {'release_id': 20481352, 'rating': {'count': 3, 'average': 5.0}}
# {'release_id': 7077894, 'rating': {'count': 6, 'average': 3.67}}
# {'release_id': 7289098, 'rating': {'count': 13, 'average': 3.46}}
# {'release_id': 7213688, 'rating': {'count': 185, 'average': 4.29}}
# {'release_id': 20481418, 'rating': {'count': 20, 'average': 4.3}}
# {'release_id': 7721779, 'rating': {'count': 36, 'average': 4.5}}
# {'release_id': 7943811, 'rating': {'count': 3, 'average': 3.33}}
# {'release_id': 21454171, 'rating': {'count': 4, 'average': 5.0}}
# {'release_id': 7805062, 'rating': {'count': 48, 'average': 4.42}}
# {'release_id': 21459289, 'rating': {'count': 3, 'average': 4.67}}
# {'release_id': 7972136, 'rating': {'count': 4, 'average': 3.75}}
# {'release_id': 8546102, 'rating': {'count': 4, 'average': 3.75}}
# {'release_id': 8603454, 'rating': {'count': 2, 'average': 4.0}}
# {'release_id': 8658694, 'rating': {'count': 54, 'average': 4.41}}
# {'release_id': 25296820, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 9020115, 'rating': {'count': 5, 'average': 3.4}}
# {'release_id': 8800052, 'rating': {'count': 44, 'average': 4.45}}
# {'release_id': 9081991, 'rating': {'count': 40, 'average': 4.48}}
# {'release_id': 13281059, 'rating': {'count': 2, 'average': 3.5}}
# {'release_id': 11442221, 'rating': {'count': 4, 'average': 4.0}}
# {'release_id': 13281047, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 9268387, 'rating': {'count': 42, 'average': 4.4}}
# {'release_id': 13235137, 'rating': {'count': 1, 'average': 4.0}}
# {'release_id': 9445368, 'rating': {'count': 52, 'average': 4.37}}
# {'release_id': 18370783, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 12044565, 'rating': {'count': 2, 'average': 4.5}}
# {'release_id': 10477649, 'rating': {'count': 33, 'average': 4.64}}
# {'release_id': 11024821, 'rating': {'count': 5, 'average': 2.2}}
# {'release_id': 10536213, 'rating': {'count': 70, 'average': 4.27}}
# {'release_id': 22842263, 'rating': {'count': 1, 'average': 3.0}}
# {'release_id': 10689824, 'rating': {'count': 73, 'average': 4.4}}
# {'release_id': 10945046, 'rating': {'count': 57, 'average': 4.49}}
# {'release_id': 11143870, 'rating': {'count': 77, 'average': 4.77}}
# {'release_id': 22484837, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 26056036, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 25297117, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 11258282, 'rating': {'count': 28, 'average': 4.68}}
# {'release_id': 22088110, 'rating': {'count': 5, 'average': 5.0}}
# {'release_id': 11299154, 'rating': {'count': 5, 'average': 4.4}}
# {'release_id': 22650743, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 12252717, 'rating': {'count': 68, 'average': 4.46}}
# {'release_id': 12376575, 'rating': {'count': 5, 'average': 4.0}}
# {'release_id': 12294503, 'rating': {'count': 52, 'average': 4.29}}
# {'release_id': 13280618, 'rating': {'count': 3, 'average': 4.33}}
# {'release_id': 12956894, 'rating': {'count': 6, 'average': 4.5}}
# {'release_id': 12999413, 'rating': {'count': 20, 'average': 4.45}}
# {'release_id': 14134549, 'rating': {'count': 1, 'average': 4.0}}
# {'release_id': 18378958, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 13717689, 'rating': {'count': 29, 'average': 4.52}}
# {'release_id': 13915901, 'rating': {'count': 64, 'average': 4.34}}
# {'release_id': 13982278, 'rating': {'count': 50, 'average': 4.68}}
# {'release_id': 14703483, 'rating': {'count': 27, 'average': 4.7}}
# {'release_id': 14984935, 'rating': {'count': 10, 'average': 4.2}}
# {'release_id': 28520992, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 15724170, 'rating': {'count': 21, 'average': 4.24}}
# {'release_id': 15762698, 'rating': {'count': 1, 'average': 4.0}}
# {'release_id': 22407970, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 16039145, 'rating': {'count': 2, 'average': 4.5}}
# {'release_id': 15906160, 'rating': {'count': 6, 'average': 4.33}}
# {'release_id': 26558294, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 16917993, 'rating': {'count': 39, 'average': 4.51}}
# {'release_id': 18450988, 'rating': {'count': 1, 'average': 4.0}}
# {'release_id': 26558285, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 20192506, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 16917921, 'rating': {'count': 29, 'average': 4.38}}
# {'release_id': 19605109, 'rating': {'count': 4, 'average': 4.0}}
# {'release_id': 18019900, 'rating': {'count': 42, 'average': 4.76}}
# {'release_id': 26558246, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 26558276, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 26558261, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 23100734, 'rating': {'count': 10, 'average': 4.8}}
# {'release_id': 26558231, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 26558219, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 25237951, 'rating': {'count': 5, 'average': 5.0}}
# {'release_id': 23223176, 'rating': {'count': 4, 'average': 2.5}}
# {'release_id': 26558207, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 24645107, 'rating': {'count': 24, 'average': 4.38}}
# {'release_id': 25352761, 'rating': {'count': 6, 'average': 3.5}}
# {'release_id': 25352788, 'rating': {'count': 4, 'average': 4.0}}
# {'release_id': 26558192, 'rating': {'count': 1, 'average': 1.0}}
# {'release_id': 25276819, 'rating': {'count': 3, 'average': 3.67}}
# {'release_id': 28501180, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 25413871, 'rating': {'count': 3, 'average': 2.0}}
# {'release_id': 27246489, 'rating': {'count': 2, 'average': 3.0}}
# {'release_id': 29146294, 'rating': {'count': 0, 'average': 0.0}}
# {'release_id': 12703540, 'rating': {'count': 12, 'average': 5.0}}
# {'release_id': 12689487, 'rating': {'count': 30, 'average': 4.37}}
# {'release_id': 12693174, 'rating': {'count': 13, 'average': 4.77}}
# {'release_id': 15536429, 'rating': {'count': 10, 'average': 3.6}}
# {'release_id': 16347822, 'rating': {'count': 3, 'average': 2.67}}

# %%
# Filter releases with average >= min_average
filtered_rating_list = [item for item in unique_rating_list if item["rating"]["average"] >= min_average]

# Debug
print("##### DEBUG #####")
for item in filtered_rating_list:
    print(item)
# Out:
# ##### DEBUG #####
# {'release_id': 23474363, 'rating': {'count': 5, 'average': 4.8}}
# {'release_id': 11281777, 'rating': {'count': 100, 'average': 4.82}}
# {'release_id': 14459372, 'rating': {'count': 54, 'average': 4.76}}
# {'release_id': 13280954, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 11030620, 'rating': {'count': 37, 'average': 4.84}}
# {'release_id': 20481352, 'rating': {'count': 3, 'average': 5.0}}
# {'release_id': 21454171, 'rating': {'count': 4, 'average': 5.0}}
# {'release_id': 18370783, 'rating': {'count': 1, 'average': 5.0}}
# {'release_id': 11143870, 'rating': {'count': 77, 'average': 4.77}}
# {'release_id': 22088110, 'rating': {'count': 5, 'average': 5.0}}
# {'release_id': 14703483, 'rating': {'count': 27, 'average': 4.7}}
# {'release_id': 18019900, 'rating': {'count': 42, 'average': 4.76}}
# {'release_id': 23100734, 'rating': {'count': 10, 'average': 4.8}}
# {'release_id': 25237951, 'rating': {'count': 5, 'average': 5.0}}
# {'release_id': 12703540, 'rating': {'count': 12, 'average': 5.0}}
# {'release_id': 12693174, 'rating': {'count': 13, 'average': 4.77}}

# %%
# Create a list with the matching releases
matching_releases_list = create_matching_releases(response_label_dict, filtered_rating_list)

# Debug
print("##### DEBUG #####")
print("length matching_releases: " + str(len(matching_releases_list)))
for item in matching_releases_list:
   print(json.dumps(item, indent=4))
# Out:
# ##### DEBUG #####
# length matching_releases: 18
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "5xFile, FLAC, EP",
#         "catno": "none",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/23474363",
#         "title": "The Botox Queen",
#         "id": 23474363,
#         "year": 2022,
#         "artist": "Vladimir Dubyshkin"
#     },
#     "rating_info": {
#         "count": 5,
#         "average": 4.8
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\", Album",
#         "catno": "TRP019, trip 19",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/11281777",
#         "title": "\u041f\u0430\u0440\u0430\u0434\u043e\u043a\u0441 = Paradox",
#         "id": 11281777,
#         "year": 2017,
#         "artist": "Aleksi Per\u00e4l\u00e4"
#     },
#     "rating_info": {
#         "count": 100,
#         "average": 4.82
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\", Album",
#         "catno": "TRP028, trip 28",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/14459372",
#         "title": "\u0420\u0435\u0437\u043e\u043d\u0430\u043d\u0441 = Resonance",
#         "id": 14459372,
#         "year": 2019,
#         "artist": "Aleksi Per\u00e4l\u00e4"
#     },
#     "rating_info": {
#         "count": 54,
#         "average": 4.76
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "13xFile, FLAC, Album",
#         "catno": "TRP 007",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/13280954",
#         "title": "\u0411 = B ",
#         "id": 13280954,
#         "year": 2016,
#         "artist": "Bjarki"
#     },
#     "rating_info": {
#         "count": 1,
#         "average": 5.0
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "12\", Ltd, S/Edition, W/Lbl, Cle",
#         "catno": "TRP ADE PT 3",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/11030620",
#         "title": "TRP ADE PT 3",
#         "id": 11030620,
#         "year": 2017,
#         "artist": "DJ Rush / K-Hand*"
#     },
#     "rating_info": {
#         "count": 37,
#         "average": 4.84
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\", Comp, RP",
#         "catno": "TRP002",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/20481352",
#         "title": "De Niro Is Concerned",
#         "id": 20481352,
#         "year": 2021,
#         "artist": "Various"
#     },
#     "rating_info": {
#         "count": 3,
#         "average": 5.0
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\", Comp, RP",
#         "catno": "TRP004",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/21454171",
#         "title": "\u0418\u0432\u0430\u043d, \u0414\u0430\u0432\u0430\u0439! \u041e\u0442\u043a\u0440\u043e\u0439 \u041a\u043e\u0440\u043e\u0431\u043a\u0443! = Ivan, Come On, Unlock The Box ",
#         "id": 21454171,
#         "year": 2021,
#         "artist": "Various"
#     },
#     "rating_info": {
#         "count": 4,
#         "average": 5.0
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "12\", EP, TP, W/Lbl, 140",
#         "catno": "TRP011",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/18370783",
#         "title": " \u0421\u0432\u0435\u0436\u0438\u0439 \u0414\u0436\u0430\u0439\u0432 = Fresh Jive",
#         "id": 18370783,
#         "year": 2016,
#         "artist": "Bjarki"
#     },
#     "rating_info": {
#         "count": 1,
#         "average": 5.0
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "12\"",
#         "catno": "TRP017",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/11143870",
#         "title": "Hessdalen",
#         "id": 11143870,
#         "year": 2017,
#         "artist": "Volruptus"
#     },
#     "rating_info": {
#         "count": 77,
#         "average": 4.77
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\"",
#         "catno": "TRP019",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/22088110",
#         "title": "Paradox",
#         "id": 22088110,
#         "year": 2022,
#         "artist": "Aleksi Per\u00e4l\u00e4"
#     },
#     "rating_info": {
#         "count": 5,
#         "average": 5.0
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\", Album",
#         "catno": "TRP019, trip 19",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/11281777",
#         "title": "\u041f\u0430\u0440\u0430\u0434\u043e\u043a\u0441 = Paradox",
#         "id": 11281777,
#         "year": 2017,
#         "artist": "Aleksi Per\u00e4l\u00e4"
#     },
#     "rating_info": {
#         "count": 100,
#         "average": 4.82
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\", Album",
#         "catno": "TRP028, trip 28",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/14459372",
#         "title": "\u0420\u0435\u0437\u043e\u043d\u0430\u043d\u0441 = Resonance",
#         "id": 14459372,
#         "year": 2019,
#         "artist": "Aleksi Per\u00e4l\u00e4"
#     },
#     "rating_info": {
#         "count": 54,
#         "average": 4.76
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\", Comp",
#         "catno": "TRP029",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/14703483",
#         "title": "Locus Error",
#         "id": 14703483,
#         "year": 2020,
#         "artist": "Various"
#     },
#     "rating_info": {
#         "count": 27,
#         "average": 4.7
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\", Album",
#         "catno": "TRP035",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/18019900",
#         "title": "Green Trax",
#         "id": 18019900,
#         "year": 2021,
#         "artist": "Steve O'Sullivan"
#     },
#     "rating_info": {
#         "count": 42,
#         "average": 4.76
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2x12\"",
#         "catno": "TRP037",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/23100734",
#         "title": "Iteritax",
#         "id": 23100734,
#         "year": 2022,
#         "artist": "Cerrot"
#     },
#     "rating_info": {
#         "count": 10,
#         "average": 4.8
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "2xLP",
#         "catno": "TRP038",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/25237951",
#         "title": "All His Decisions",
#         "id": 25237951,
#         "year": 2022,
#         "artist": "Various"
#     },
#     "rating_info": {
#         "count": 5,
#         "average": 5.0
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "12\", W/Lbl",
#         "catno": "Trpade2018pt1",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/12703540",
#         "title": "Trip ADE 2018 PT1",
#         "id": 12703540,
#         "year": 2018,
#         "artist": "Roma Zuckerman"
#     },
#     "rating_info": {
#         "count": 12,
#         "average": 5.0
#     }
# }
# {
#     "release_info": {
#         "status": "Accepted",
#         "format": "12\", Ltd, W/Lbl",
#         "catno": "Trpade2018pt3",
#         "thumb": "",
#         "resource_url": "https://api.discogs.com/releases/12693174",
#         "title": "Trip ADE 2018 PT3",
#         "id": 12693174,
#         "year": 2018,
#         "artist": "Various"
#     },
#     "rating_info": {
#         "count": 13,
#         "average": 4.77
#     }
# }

# %%
# Remove duplicates from matching_releases_list based on the "id" key
unique_matching_list = remove_duplicates(matching_releases_list, ["release_info", "id"])

# Debug
print("##### DEBUG #####")
print("length unique_matching_list: " + str(len(unique_matching_list)))
for release in unique_matching_list:
    print("Release Info:")
    print(json.dumps(release["release_info"], indent=4))
    print("Rating Info:")
    print(json.dumps(release["rating_info"], indent=4))
    print()
# Out:
# ##### DEBUG #####
# length unique_matching_list: 16
# Release Info:
# {
#     "status": "Accepted",
#     "format": "5xFile, FLAC, EP",
#     "catno": "none",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/23474363",
#     "title": "The Botox Queen",
#     "id": 23474363,
#     "year": 2022,
#     "artist": "Vladimir Dubyshkin"
# }
# Rating Info:
# {
#     "count": 5,
#     "average": 4.8
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2x12\", Album",
#     "catno": "TRP019, trip 19",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/11281777",
#     "title": "\u041f\u0430\u0440\u0430\u0434\u043e\u043a\u0441 = Paradox",
#     "id": 11281777,
#     "year": 2017,
#     "artist": "Aleksi Per\u00e4l\u00e4"
# }
# Rating Info:
# {
#     "count": 100,
#     "average": 4.82
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2x12\", Album",
#     "catno": "TRP028, trip 28",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/14459372",
#     "title": "\u0420\u0435\u0437\u043e\u043d\u0430\u043d\u0441 = Resonance",
#     "id": 14459372,
#     "year": 2019,
#     "artist": "Aleksi Per\u00e4l\u00e4"
# }
# Rating Info:
# {
#     "count": 54,
#     "average": 4.76
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "13xFile, FLAC, Album",
#     "catno": "TRP 007",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/13280954",
#     "title": "\u0411 = B ",
#     "id": 13280954,
#     "year": 2016,
#     "artist": "Bjarki"
# }
# Rating Info:
# {
#     "count": 1,
#     "average": 5.0
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\", Ltd, S/Edition, W/Lbl, Cle",
#     "catno": "TRP ADE PT 3",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/11030620",
#     "title": "TRP ADE PT 3",
#     "id": 11030620,
#     "year": 2017,
#     "artist": "DJ Rush / K-Hand*"
# }
# Rating Info:
# {
#     "count": 37,
#     "average": 4.84
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2x12\", Comp, RP",
#     "catno": "TRP002",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/20481352",
#     "title": "De Niro Is Concerned",
#     "id": 20481352,
#     "year": 2021,
#     "artist": "Various"
# }
# Rating Info:
# {
#     "count": 3,
#     "average": 5.0
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2x12\", Comp, RP",
#     "catno": "TRP004",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/21454171",
#     "title": "\u0418\u0432\u0430\u043d, \u0414\u0430\u0432\u0430\u0439! \u041e\u0442\u043a\u0440\u043e\u0439 \u041a\u043e\u0440\u043e\u0431\u043a\u0443! = Ivan, Come On, Unlock The Box ",
#     "id": 21454171,
#     "year": 2021,
#     "artist": "Various"
# }
# Rating Info:
# {
#     "count": 4,
#     "average": 5.0
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\", EP, TP, W/Lbl, 140",
#     "catno": "TRP011",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/18370783",
#     "title": " \u0421\u0432\u0435\u0436\u0438\u0439 \u0414\u0436\u0430\u0439\u0432 = Fresh Jive",
#     "id": 18370783,
#     "year": 2016,
#     "artist": "Bjarki"
# }
# Rating Info:
# {
#     "count": 1,
#     "average": 5.0
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\"",
#     "catno": "TRP017",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/11143870",
#     "title": "Hessdalen",
#     "id": 11143870,
#     "year": 2017,
#     "artist": "Volruptus"
# }
# Rating Info:
# {
#     "count": 77,
#     "average": 4.77
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2x12\"",
#     "catno": "TRP019",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/22088110",
#     "title": "Paradox",
#     "id": 22088110,
#     "year": 2022,
#     "artist": "Aleksi Per\u00e4l\u00e4"
# }
# Rating Info:
# {
#     "count": 5,
#     "average": 5.0
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2x12\", Comp",
#     "catno": "TRP029",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/14703483",
#     "title": "Locus Error",
#     "id": 14703483,
#     "year": 2020,
#     "artist": "Various"
# }
# Rating Info:
# {
#     "count": 27,
#     "average": 4.7
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2x12\", Album",
#     "catno": "TRP035",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/18019900",
#     "title": "Green Trax",
#     "id": 18019900,
#     "year": 2021,
#     "artist": "Steve O'Sullivan"
# }
# Rating Info:
# {
#     "count": 42,
#     "average": 4.76
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2x12\"",
#     "catno": "TRP037",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/23100734",
#     "title": "Iteritax",
#     "id": 23100734,
#     "year": 2022,
#     "artist": "Cerrot"
# }
# Rating Info:
# {
#     "count": 10,
#     "average": 4.8
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "2xLP",
#     "catno": "TRP038",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/25237951",
#     "title": "All His Decisions",
#     "id": 25237951,
#     "year": 2022,
#     "artist": "Various"
# }
# Rating Info:
# {
#     "count": 5,
#     "average": 5.0
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\", W/Lbl",
#     "catno": "Trpade2018pt1",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/12703540",
#     "title": "Trip ADE 2018 PT1",
#     "id": 12703540,
#     "year": 2018,
#     "artist": "Roma Zuckerman"
# }
# Rating Info:
# {
#     "count": 12,
#     "average": 5.0
# }
#
# Release Info:
# {
#     "status": "Accepted",
#     "format": "12\", Ltd, W/Lbl",
#     "catno": "Trpade2018pt3",
#     "thumb": "",
#     "resource_url": "https://api.discogs.com/releases/12693174",
#     "title": "Trip ADE 2018 PT3",
#     "id": 12693174,
#     "year": 2018,
#     "artist": "Various"
# }
# Rating Info:
# {
#     "count": 13,
#     "average": 4.77
# }

# %%
# Create specific output
output_list = create_output_list(unique_matching_list)

# print(output_list)
print(json.dumps(output_list, indent=4))
# Out:
# [
#     {
#         "catno": "none",
#         "artist": "Vladimir Dubyshkin",
#         "title": "The Botox Queen",
#         "year": 2022,
#         "format": "5xFile, FLAC, EP",
#         "url": "https://www.discogs.com/es/release/23474363",
#         "rating": {
#             "count": 5,
#             "average": 4.8
#         }
#     },
#     {
#         "catno": "TRP019, trip 19",
#         "artist": "Aleksi Per\u00e4l\u00e4",
#         "title": "\u041f\u0430\u0440\u0430\u0434\u043e\u043a\u0441 = Paradox",
#         "year": 2017,
#         "format": "2x12\", Album",
#         "url": "https://www.discogs.com/es/release/11281777",
#         "rating": {
#             "count": 100,
#             "average": 4.82
#         }
#     },
#     {
#         "catno": "TRP028, trip 28",
#         "artist": "Aleksi Per\u00e4l\u00e4",
#         "title": "\u0420\u0435\u0437\u043e\u043d\u0430\u043d\u0441 = Resonance",
#         "year": 2019,
#         "format": "2x12\", Album",
#         "url": "https://www.discogs.com/es/release/14459372",
#         "rating": {
#             "count": 54,
#             "average": 4.76
#         }
#     },
#     {
#         "catno": "TRP 007",
#         "artist": "Bjarki",
#         "title": "\u0411 = B ",
#         "year": 2016,
#         "format": "13xFile, FLAC, Album",
#         "url": "https://www.discogs.com/es/release/13280954",
#         "rating": {
#             "count": 1,
#             "average": 5.0
#         }
#     },
#     {
#         "catno": "TRP ADE PT 3",
#         "artist": "DJ Rush / K-Hand*",
#         "title": "TRP ADE PT 3",
#         "year": 2017,
#         "format": "12\", Ltd, S/Edition, W/Lbl, Cle",
#         "url": "https://www.discogs.com/es/release/11030620",
#         "rating": {
#             "count": 37,
#             "average": 4.84
#         }
#     },
#     {
#         "catno": "TRP002",
#         "artist": "Various",
#         "title": "De Niro Is Concerned",
#         "year": 2021,
#         "format": "2x12\", Comp, RP",
#         "url": "https://www.discogs.com/es/release/20481352",
#         "rating": {
#             "count": 3,
#             "average": 5.0
#         }
#     },
#     {
#         "catno": "TRP004",
#         "artist": "Various",
#         "title": "\u0418\u0432\u0430\u043d, \u0414\u0430\u0432\u0430\u0439! \u041e\u0442\u043a\u0440\u043e\u0439 \u041a\u043e\u0440\u043e\u0431\u043a\u0443! = Ivan, Come On, Unlock The Box ",
#         "year": 2021,
#         "format": "2x12\", Comp, RP",
#         "url": "https://www.discogs.com/es/release/21454171",
#         "rating": {
#             "count": 4,
#             "average": 5.0
#         }
#     },
#     {
#         "catno": "TRP011",
#         "artist": "Bjarki",
#         "title": " \u0421\u0432\u0435\u0436\u0438\u0439 \u0414\u0436\u0430\u0439\u0432 = Fresh Jive",
#         "year": 2016,
#         "format": "12\", EP, TP, W/Lbl, 140",
#         "url": "https://www.discogs.com/es/release/18370783",
#         "rating": {
#             "count": 1,
#             "average": 5.0
#         }
#     },
#     {
#         "catno": "TRP017",
#         "artist": "Volruptus",
#         "title": "Hessdalen",
#         "year": 2017,
#         "format": "12\"",
#         "url": "https://www.discogs.com/es/release/11143870",
#         "rating": {
#             "count": 77,
#             "average": 4.77
#         }
#     },
#     {
#         "catno": "TRP019",
#         "artist": "Aleksi Per\u00e4l\u00e4",
#         "title": "Paradox",
#         "year": 2022,
#         "format": "2x12\"",
#         "url": "https://www.discogs.com/es/release/22088110",
#         "rating": {
#             "count": 5,
#             "average": 5.0
#         }
#     },
#     {
#         "catno": "TRP029",
#         "artist": "Various",
#         "title": "Locus Error",
#         "year": 2020,
#         "format": "2x12\", Comp",
#         "url": "https://www.discogs.com/es/release/14703483",
#         "rating": {
#             "count": 27,
#             "average": 4.7
#         }
#     },
#     {
#         "catno": "TRP035",
#         "artist": "Steve O'Sullivan",
#         "title": "Green Trax",
#         "year": 2021,
#         "format": "2x12\", Album",
#         "url": "https://www.discogs.com/es/release/18019900",
#         "rating": {
#             "count": 42,
#             "average": 4.76
#         }
#     },
#     {
#         "catno": "TRP037",
#         "artist": "Cerrot",
#         "title": "Iteritax",
#         "year": 2022,
#         "format": "2x12\"",
#         "url": "https://www.discogs.com/es/release/23100734",
#         "rating": {
#             "count": 10,
#             "average": 4.8
#         }
#     },
#     {
#         "catno": "TRP038",
#         "artist": "Various",
#         "title": "All His Decisions",
#         "year": 2022,
#         "format": "2xLP",
#         "url": "https://www.discogs.com/es/release/25237951",
#         "rating": {
#             "count": 5,
#             "average": 5.0
#         }
#     },
#     {
#         "catno": "Trpade2018pt1",
#         "artist": "Roma Zuckerman",
#         "title": "Trip ADE 2018 PT1",
#         "year": 2018,
#         "format": "12\", W/Lbl",
#         "url": "https://www.discogs.com/es/release/12703540",
#         "rating": {
#             "count": 12,
#             "average": 5.0
#         }
#     },
#     {
#         "catno": "Trpade2018pt3",
#         "artist": "Various",
#         "title": "Trip ADE 2018 PT3",
#         "year": 2018,
#         "format": "12\", Ltd, W/Lbl",
#         "url": "https://www.discogs.com/es/release/12693174",
#         "rating": {
#             "count": 13,
#             "average": 4.77
#         }
#     }
# ]
